# %% [markdown]
# <a href="https://colab.research.google.com/github/trabuco1113-9611/Inteligencia-Artificial/blob/main/carpeta/modelo%20de%20prediccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Generar dataset sintético con diferentes rangos por habilidad
n_muestras = 5000
# Habilidades técnicas: 70-100
tec = np.random.randint(70, 101, (n_muestras, 6))
# Habilidades matemáticas: 60-90
mat = np.random.randint(60, 91, (n_muestras, 6))
# Habilidades psicológicas: 50-85
psi = np.random.randint(50, 86, (n_muestras, 6))
# Nombres de columnas
columnas = [
    'python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube',
    'estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado',
    'trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas'
]
# Crear DataFrame
df = pd.DataFrame(np.concatenate([tec, mat, psi], axis=1), columns=columnas)

# %%
df
# Out:
#       python  sql  visualizacion_datos  excel  manejo_apis  nube  estadistica  \
# 0         75   94                   94     89           84    81           70
# 1         90   85                   77     92           94    95           69
# 2         77   81                   74     93           94    78           88
# 3         98   97                   92     71           72    76           60
# 4         75   96                   82     88           77    70           65
# ...      ...  ...                  ...    ...          ...   ...          ...
# 4995      77   95                   97    100           81    78           87
# 4996      74   86                   72     84           92    99           72
# 4997      94   81                   98     70           86    81           77
# 4998      81   75                   70     71           81    86           64
# 4999      95   70                   74     75           93    74           60
#
#       probabilidad  algebra_lineal  calculo  optimizacion  modelado  \
# 0               74              72       81            65        80
# 1               78              62       82            89        64
# 2               84              65       63            88        82
# 3               62              80       75            71        90
# 4               62              75       71            62        78
# ...            ...             ...      ...           ...       ...
# 4995            88              82       78            85        68
# 4996            87              86       71            70        71
# 4997            88              88       76            81        67
# 4998            61              79       73            64        62
# 4999            90              79       75            83        63
#
#       trabajo_equipo  comunicacion  creatividad  adaptabilidad  liderazgo  \
# 0                 61            78           75             64         79
# 1                 68            59           57             69         62
# 2                 63            56           57             65         64
# 3                 85            50           62             82         84
# 4                 77            65           55             53         59
# ...              ...           ...          ...            ...        ...
# 4995              83            65           73             53         52
# 4996              83            76           75             73         64
# 4997              60            52           83             84         68
# 4998              79            63           84             59         85
# 4999              74            79           51             81         68
#
#       resolucion_problemas
# 0                       76
# 1                       60
# 2                       67
# 3                       79
# 4                       69
# ...                    ...
# 4995                    78
# 4996                    67
# 4997                    85
# 4998                    79
# 4999                    81
#
# [5000 rows x 18 columns]

# %%
# Calcular promedio por grupo y promedio total
prom_tecnologicas = df[['python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube']].mean(axis=1)
prom_matematicas  = df[['estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado']].mean(axis=1)
prom_psicologicas = df[['trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas']].mean(axis=1)
# Promedio total = promedio de los 3 promedios
prom_total = (prom_tecnologicas + prom_matematicas + prom_psicologicas) / 3
# Etiqueta: 1 = apto si promedio total > 80
y = (prom_total > 75).astype(int)
# one-hot encoding
y = pd.get_dummies(y).values

# %%
df.describe()
# Out:
#             python          sql  visualizacion_datos        excel  \
# count  5000.000000  5000.000000          5000.000000  5000.000000
# mean     84.989800    85.042600            85.095200    85.191000
# std       8.904783     8.860569             8.903886     8.965076
# min      70.000000    70.000000            70.000000    70.000000
# 25%      77.000000    77.000000            77.000000    77.000000
# 50%      85.000000    85.000000            85.000000    85.000000
# 75%      93.000000    93.000000            93.000000    93.000000
# max     100.000000   100.000000           100.000000   100.000000
#
#        manejo_apis         nube  estadistica  probabilidad  algebra_lineal  \
# count  5000.000000  5000.000000  5000.000000   5000.000000     5000.000000
# mean     85.103200    84.982400    74.963600     75.054000       75.022000
# std       8.985694     8.896174     8.936053      8.934352        8.937175
# min      70.000000    70.000000    60.000000     60.000000       60.000000
# 25%      77.000000    77.000000    67.000000     67.000000       67.000000
# 50%      85.000000    85.000000    75.000000     75.000000       75.000000
# 75%      93.000000    93.000000    83.000000     83.000000       83.000000
# max     100.000000   100.000000    90.000000     90.000000       90.000000
#
#            calculo  optimizacion     modelado  trabajo_equipo  comunicacion  \
# count  5000.000000   5000.000000  5000.000000     5000.000000   5000.000000
# mean     74.984400     74.924200    74.871000       67.433600     67.675400
# std       8.885648      8.969757     8.825324       10.439128     10.426494
# min      60.000000     60.000000    60.000000       50.000000     50.000000
# 25%      67.000000     67.000000    67.000000       58.000000     59.000000
# 50%      75.000000     75.000000    75.000000       67.000000     68.000000
# 75%      82.250000     83.000000    82.000000       77.000000     77.000000
# max      90.000000     90.000000    90.000000       85.000000     85.000000
#
#        creatividad  adaptabilidad    liderazgo  resolucion_problemas
# count   5000.00000    5000.000000  5000.000000           5000.000000
# mean      67.36140      67.385200    67.796400             67.427400
# std       10.27552      10.440873    10.488401             10.458748
# min       50.00000      50.000000    50.000000             50.000000
# 25%       58.00000      58.000000    58.000000             58.000000
# 50%       67.00000      67.000000    68.000000             67.000000
# 75%       76.00000      76.000000    77.000000             77.000000
# max       85.00000      85.000000    85.000000             85.000000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)

# Escalamiento
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
X_test.shape
# Out:
# (1000, 18)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

adam = Adam(learning_rate=0.001)
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = modelo.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 6.5229e-06 - val_accuracy: 0.9730 - val_loss: 0.1638
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.6307e-06 - val_accuracy: 0.9730 - val_loss: 0.1665
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.3543e-06 - val_accuracy: 0.9720 - val_loss: 0.1691
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.1827e-06 - val_accuracy: 0.9730 - val_loss: 0.1700
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.8906e-06 - val_accuracy: 0.9720 - val_loss: 0.1741
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.5569e-06 - val_accuracy: 0.9720 - val_loss: 0.1766
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0927e-06 - val_accuracy: 0.9730 - val_loss: 0.1793
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 7.6782e-07 - val_accuracy: 0.9710 - val_loss: 0.1809
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.3144e-07 - val_accuracy: 0.9710 - val_loss: 0.1853
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.6255e-07 - val_accuracy: 0.9720 - val_loss: 0.1883
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.6239e-07 - val_accuracy: 0.9720 - val_loss: 0.1909
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.6357e-07 - val_accuracy: 0.9720 - val_loss: 0.1934
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.2314e-07 - val_accuracy: 0.9720 - val_loss: 0.1962
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.6082e-07 - val_accuracy: 0.9730 - val_loss: 0.1997
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3315e-07 - val_accuracy: 0.9730 - val_loss: 0.2025
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.0500e-07 - val_accuracy: 0.9720 - val_loss: 0.2057
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.1615e-08 - val_accuracy: 0.9730 - val_loss: 0.2101
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.9660e-08 - val_accuracy: 0.9740 - val_loss: 0.2147
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.8862e-08 - val_accuracy: 0.9730 - val_loss: 0.2164
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.4481e-08 - val_accuracy: 0.9730 - val_loss: 0.2215
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.5682e-08 - val_accuracy: 0.9710 - val_loss: 0.2237
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6051e-08 - val_accuracy: 0.9730 - val_loss: 0.2260
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.5588e-08 - val_accuracy: 0.9740 - val_loss: 0.2276
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.0983e-08 - val_accuracy: 0.9720 - val_loss: 0.2318
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.4707e-09 - val_accuracy: 0.9730 - val_loss: 0.2332
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.6149e-09 - val_accuracy: 0.9720 - val_loss: 0.2379
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 5.8150e-09 - val_accuracy: 0.9700 - val_loss: 0.2403
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.2574e-09 - val_accuracy: 0.9720 - val_loss: 0.2432
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.3057e-09 - val_accuracy: 0.9700 - val_loss: 0.2480
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.7151e-09 - val_accuracy: 0.9700 - val_loss: 0.2496
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.3320e-09 - val_accuracy: 0.9700 - val_loss: 0.2527
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.0237e-09 - val_accuracy: 0.9690 - val_loss: 0.2554
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.1171e-10 - val_accuracy: 0.9710 - val_loss: 0.2555
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.0630e-10 - val_accuracy: 0.9700 - val_loss: 0.2589
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.9113e-10 - val_accuracy: 0.9700 - val_loss: 0.2596
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.9625e-10 - val_accuracy: 0.9700 - val_loss: 0.2588
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.5702e-11 - val_accuracy: 0.9710 - val_loss: 0.2630
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9710 - val_loss: 0.2630
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9690 - val_loss: 0.2650
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9700 - val_loss: 0.2645
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9710 - val_loss: 0.2670
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9710 - val_loss: 0.2688
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9710 - val_loss: 0.2697
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9720 - val_loss: 0.2695
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9720 - val_loss: 0.2718
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9700 - val_loss: 0.2720
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9710 - val_loss: 0.2732
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9720 - val_loss: 0.2736
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9720 - val_loss: 0.2752
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9720 - val_loss: 0.2753

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

loss, acc = modelo.evaluate(X_test, y_test)
print(f"\n🔹 Loss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.1916
#
# 🔹 Loss: 0.2753  |  Accuracy: 0.9720

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.96
# Apto: 0.98

# %%
# @title Texto de título predeterminado

variable_name = 0 # @param {"type":"integer","placeholder":"esto es lo que se cuando un campo esta aguardado"}

nuevo_candidato = np.array([[90, 88, 85, 87, 84, 89,   # técnicas
                             82, 86, 85, 83, 87, 80,   # matemáticas
                             70, 75, 80, 72, 78, 74]]) # psicológicas

nuevo_candidato_scaled = scaler.transform(nuevo_candidato)
pred_nuevo = modelo.predict(nuevo_candidato_scaled)
clase_predicha = np.argmax(pred_nuevo)

print("Evaluación de nuevo candidato:")
print(f"Resultado: {'Apto' if clase_predicha == 1 else 'No Apto'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Evaluación de nuevo candidato:
# Resultado: Apto
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
